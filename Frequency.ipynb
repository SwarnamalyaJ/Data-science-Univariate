# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#main purpose of dataset is find qual and quan
#the dataset based on company Placement
#qual menans=object(category)
#quan(int,float),(numerical)

# %%
#info function using for separate the row and columns shows total num of float64(6), int64(1), object(8),and shows total num of rows and columns.() is open parathasis
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
#cloumns function using of list only columns names
dataset.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
#now we need a separation of datatype ,and we need this type of separation is need (write a logic)
#qual=['gender','ssc_b','hsc_b','hsc_s','degree_t','workex','specialisation','status']
#quan=['sl_no','ssc_p','hsc_p','degree_p','mba_p','salary']

# %%
#now qual and quan working under some function ,list of all the attributes and methods associated with pandas DataFrames.
dir(dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
#dataset["gender"] selects the column named "gender" from your dataset.
#.dtypes is an attribute of a pandas Series object, which returns the data type of the values 
#dataset["gender"].dtypes will return the data type of the values in the "gender" column of your dataset. 
#"o" denoted as object 
dataset["ssc_p"].dtypes
# Out:
# dtype('float64')

# %%
for columnname in dataset.columns:
    print(columnname)
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
#last output dtype("o"),using this method means take too much time so use "if" 
#Assuming dataset is a DataFrame and "gender" is a column in it
#("quan","qual")Checking if the datatype is object (string)
if(dataset["gender"].dtypes=="o"):
    print("qual")
else:
    print("quan")
# Out:
# quan

# %%
quan=[]
qual=[]
for columnName in dataset.columns:
    #print(columnName)
    if(dataset[columnName].dtype=='O'):
        #print("qual")
        qual.append(columnName)
    else:
        #print("quan")
        quan.append(columnName)

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
def Univariate(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
Univariate(dataset)
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
quan,qual=Univariate(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %% [markdown]
# #CENTRAL TENDENCY:

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset["ssc_p"].mean()
# Out:
# np.float64(67.30339534883721)

# %%
dataset["ssc_p"].median()
# Out:
# np.float64(67.0)

# %%
dataset["ssc_p"].mode()
# Out:
# 0    62.0
# Name: ssc_p, dtype: float64

# %%
dataset["ssc_p"].mode()[0]
# Out:
# np.float64(62.0)

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive=pd.DataFrame()

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"])

# %%
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: [Mean, Median, Mode]

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive["hsc_p"]["Median"]
# Out:
# nan

# %%
descriptive["hsc_p"]["Median"]=0
# Out:
# C:\Users\Malya\AppData\Local\Temp\ipykernel_36156\2333899791.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive["hsc_p"]["Median"]=0

# %%
descriptive = pd.DataFrame(index=["Mean", "Median", "Mode"], columns=quan)
for columnName in quan:
    descriptive.loc["Mean", columnName] = dataset[columnName].mean()
#For creating table use this like code and use it for other all column we need
#Using .loc[]is used to specify both the row and column at the same time. This is the correct way to modify a particular element in a DataFrame

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    NaN        NaN        NaN        NaN        NaN        NaN
# Mode      NaN        NaN        NaN        NaN        NaN        NaN
#
#                salary
# Mean    288655.405405
# Median            NaN
# Mode              NaN

# %%
descriptive = pd.DataFrame(index=["Mean", "Median", "Mode"], columns=quan)
for columnName in quan:
    descriptive.loc["Mean", columnName] = dataset[columnName].mean()
    descriptive.loc["Median", columnName] = dataset[columnName].median()
    descriptive.loc["Mode", columnName] = dataset[columnName].mode()[0]

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %% [markdown]
# #PERCENTILE

# %%
import numpy as np

# %%
np.percentile(dataset["ssc_p"],50)
# Out:
# np.float64(67.0)

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%"],columns=quan)
for columnName in quan:
    descriptive.loc["Mean", columnName] = dataset[columnName].mean()
    descriptive.loc["Median", columnName] = dataset[columnName].median()
    descriptive.loc["Mode", columnName] = dataset[columnName].mode()[0]
#This is the way  to add column and rows.in next step we going to remove the NaN values instead we are assign values from dataset.

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     NaN        NaN        NaN        NaN        NaN        NaN
# Q2:50%     NaN        NaN        NaN        NaN        NaN        NaN
# Q3:75%     NaN        NaN        NaN        NaN        NaN        NaN
# Q4:100%    NaN        NaN        NaN        NaN        NaN        NaN
#
#                 salary
# Mean     288655.405405
# Median        265000.0
# Mode          300000.0
# Q1:25%             NaN
# Q2:50%             NaN
# Q3:75%             NaN
# Q4:100%            NaN

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%"],columns=quan)
for columnName in quan:
    descriptive.loc["Mean", columnName]=dataset[columnName].mean()
    descriptive.loc["Median", columnName]=dataset[columnName].median()
    descriptive.loc["Mode", columnName]=dataset[columnName].mode()[0]
    descriptive.loc["Q1:25%", columnName]=dataset.describe()[columnName]["25%"]
    descriptive.loc["Q2:50%", columnName]=dataset.describe()[columnName]["50%"]
    descriptive.loc["Q3:75%", columnName]=dataset.describe()[columnName]["75%"]
    descriptive.loc["Q4:100%", columnName]=dataset.describe()[columnName]["max"]

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4       97.7       91.0       98.0      77.89
#
#                 salary
# Mean     288655.405405
# Median        265000.0
# Mode          300000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# Q4:100%       940000.0

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnName in quan:
   descriptive.loc["Mean", columnName]=dataset[columnName].mean()
   descriptive.loc["Median", columnName]=dataset[columnName].median()
   descriptive.loc["Mode", columnName]=dataset[columnName].mode()[0]
   descriptive.loc["Q1:25%", columnName]=dataset.describe()[columnName]["25%"]
   descriptive.loc["Q2:50%", columnName]=dataset.describe()[columnName]["50%"]
   descriptive.loc["Q3:75%", columnName]=dataset.describe()[columnName]["75%"]
   descriptive.loc["Q4:100%", columnName]=dataset.describe()[columnName]["max"]
   descriptive.loc["IQR", columnName]= descriptive.loc["Q3:75%", columnName]-descriptive.loc["Q1:25%", columnName]
   descriptive.loc["1.5rule", columnName]=1.5* descriptive.loc["IQR", columnName]
   descriptive.loc["Lesser", columnName]=descriptive.loc["Q1:25%", columnName]-descriptive.loc["1.5rule", columnName]
   descriptive.loc["Greater", columnName]=descriptive.loc["Q3:75%", columnName]+descriptive.loc["1.5rule", columnName]
   descriptive.loc["Min", columnName]=dataset[columnName].min()
   descriptive.loc["Max", columnName]=dataset[columnName].max()
#Here adding IQR part ,with using IQR formula we creating this steps nd getting output

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4       97.7       91.0       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# Lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# Greater  322.0      98.35      91.15       88.5     118.75      78.72
# Min          1      40.89       37.0       50.0       50.0      51.21
# ...

# %%
##FINDING OUTLIER

# %%
descriptive["hsc_p"]["Min"]<descriptive["hsc_p"]["Lesser"]
#By this step we are comparing lesser and Min rows for finding any lesser oulier are present or not
# Out:
# np.True_

# %%
lesser=[]
Greater=[]
for columnName in quan:
    if(descriptive[columnName]["Min"])<descriptive[columnName]["Lesser"]:
        lesser.append(columnName)
    if(descriptive[columnName]["Max"])>descriptive[columnName]["Greater"]:
        Greater.append(columnName)

# %%
lesser
# Out:
# ['hsc_p']

# %%
Greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
# For columns in 'lesser', replace values that are less than the threshold with the "Lesser" value from the descriptive DataFrame
for columnName in lesser:
    dataset.loc[dataset[columnName] < descriptive.loc["Lesser", columnName], columnName] = descriptive.loc["Lesser", columnName]

# For columns in 'greater', replace values that are greater than the threshold with the "Greater" value from the descriptive DataFrame
for columnName in Greater:
    dataset.loc[dataset[columnName] > descriptive.loc["Greater", columnName], columnName] = descriptive.loc["Greater", columnName]

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnName in quan:
   descriptive.loc["Mean", columnName]=dataset[columnName].mean()
   descriptive.loc["Median", columnName]=dataset[columnName].median()
   descriptive.loc["Mode", columnName]=dataset[columnName].mode()[0]
   descriptive.loc["Q1:25%", columnName]=dataset.describe()[columnName]["25%"]
   descriptive.loc["Q2:50%", columnName]=dataset.describe()[columnName]["50%"]
   descriptive.loc["Q3:75%", columnName]=dataset.describe()[columnName]["75%"]
   descriptive.loc["Q4:100%", columnName]=dataset.describe()[columnName]["max"]
   descriptive.loc["IQR", columnName]= descriptive.loc["Q3:75%", columnName]-descriptive.loc["Q1:25%", columnName]
   descriptive.loc["1.5rule", columnName]=1.5* descriptive.loc["IQR", columnName]
   descriptive.loc["Lesser", columnName]=descriptive.loc["Q1:25%", columnName]-descriptive.loc["1.5rule", columnName]
   descriptive.loc["Greater", columnName]=descriptive.loc["Q3:75%", columnName]+descriptive.loc["1.5rule", columnName]
   descriptive.loc["Min", columnName]=dataset[columnName].min()
   descriptive.loc["Max", columnName]=dataset[columnName].max()

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4      91.15       88.5       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# Lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# Greater  322.0      98.35      91.15       88.5     118.75      78.72
# Min          1      40.89      42.75       50.0       50.0      51.21
# ...

# %%
lesser=[]
Greater=[]
for columnName in quan:
    if(descriptive[columnName]["Min"])<descriptive[columnName]["Lesser"]:
        lesser.append(columnName)
    if(descriptive[columnName]["Max"])>descriptive[columnName]["Greater"]:
        Greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
Greater
# Out:
# []

# %%
dataset["ssc_p"].value_counts()
#.value_counts()=it gives frequency values
# Out:
# ssc_p
# 62.00    11
# 63.00    10
# 67.00     9
# 73.00     9
# 52.00     9
#          ..
# 55.68     1
# 41.00     1
# 83.33     1
# 43.00     1
# 80.60     1
# Name: count, Length: 103, dtype: int64

# %%
freq_Table=pd.DataFrame(columns=["Unique_Values","Frequency","Relative_Frequency","Cumsum"])

# %%
freq_Table
# Out:
# Empty DataFrame
# Columns: [Unique_Values, Frequency, Relative_Frequency, Cumsum]
# Index: []

# %%
freq_Table["Unique_Values"]=dataset["ssc_p"].value_counts().index

# %%
freq_Table
# Out:
#      Unique_Values Frequency Relative_Frequency Cumsum
# 0            62.00       NaN                NaN    NaN
# 1            63.00       NaN                NaN    NaN
# 2            67.00       NaN                NaN    NaN
# 3            73.00       NaN                NaN    NaN
# 4            52.00       NaN                NaN    NaN
# ..             ...       ...                ...    ...
# 98           55.68       NaN                NaN    NaN
# 99           41.00       NaN                NaN    NaN
# 100          83.33       NaN                NaN    NaN
# 101          43.00       NaN                NaN    NaN
# 102          80.60       NaN                NaN    NaN
#
# [103 rows x 4 columns]

# %%
freq_Table["Unique_Values"]=dataset["ssc_p"].value_counts().index
freq_Table["Frequency"]=dataset["ssc_p"].value_counts().index
freq_Table["Relative_Frequency"]=freq_Table["Frequency"]/103
freq_Table["Cumsum"]=freq_Table["Relative_Frequency"].cumsum()

# %%
freq_Table
# Out:
#      Unique_Values  Frequency  Relative_Frequency     Cumsum
# 0            62.00      62.00            0.601942   0.601942
# 1            63.00      63.00            0.611650   1.213592
# 2            67.00      67.00            0.650485   1.864078
# 3            73.00      73.00            0.708738   2.572816
# 4            52.00      52.00            0.504854   3.077670
# ..             ...        ...                 ...        ...
# 98           55.68      55.68            0.540583  65.185437
# 99           41.00      41.00            0.398058  65.583495
# 100          83.33      83.33            0.809029  66.392524
# 101          43.00      43.00            0.417476  66.810000
# 102          80.60      80.60            0.782524  67.592524
#
# [103 rows x 4 columns]

# %%
def freq_Table(columnName, dataset):
    # Use a different name for the DataFrame variable (to avoid conflict with the function name)
    freq_table_df = pd.DataFrame()  # Initialize an empty DataFrame to store results
    
    # Access the specified column dynamically using the passed columnName
    freq_table_df["Unique_Values"] = dataset[columnName].value_counts().index
    freq_table_df["Frequency"] = dataset[columnName].value_counts().values  # Use .values to get the actual frequencies
    freq_table_df["Relative_Frequency"] = freq_table_df["Frequency"] / len(dataset)  # Divide by total number of rows
    freq_table_df["Cumsum"] = freq_table_df["Relative_Frequency"].cumsum()  # Cumulative sum of relative frequencies
    
    return freq_table_df

# %%
freq_Table(columnName, dataset)
# Out:
#     Unique_Values  Frequency  Relative_Frequency    Cumsum
# 0        300000.0         22            0.102326  0.102326
# 1        250000.0         18            0.083721  0.186047
# 2        240000.0         15            0.069767  0.255814
# 3        390000.0         15            0.069767  0.325581
# 4        260000.0          7            0.032558  0.358140
# 5        200000.0          6            0.027907  0.386047
# 6        360000.0          6            0.027907  0.413953
# 7        265000.0          6            0.027907  0.441860
# 8        275000.0          5            0.023256  0.465116
# 9        220000.0          5            0.023256  0.488372
# 10       270000.0          4            0.018605  0.506977
# 11       210000.0          4            0.018605  0.525581
# 12       350000.0          3            0.013953  0.539535
# 13       216000.0          3            0.013953  0.553488
# 14       204000.0          2            0.009302  0.562791
# ...

# %%
def Univariate(dataset,quan):
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
    for columnName in quan:
        descriptive.loc["Mean", columnName]=dataset[columnName].mean()
        descriptive.loc["Median", columnName]=dataset[columnName].median()
        descriptive.loc["Mode", columnName]=dataset[columnName].mode()[0]
        descriptive.loc["Q1:25%", columnName]=dataset.describe()[columnName]["25%"]
        descriptive.loc["Q2:50%", columnName]=dataset.describe()[columnName]["50%"]
        descriptive.loc["Q3:75%", columnName]=dataset.describe()[columnName]["75%"]
        descriptive.loc["Q4:100%", columnName]=dataset.describe()[columnName]["max"]
        descriptive.loc["IQR", columnName]= descriptive.loc["Q3:75%", columnName]-descriptive.loc["Q1:25%", columnName]
        descriptive.loc["1.5rule", columnName]=1.5* descriptive.loc["IQR", columnName]
        descriptive.loc["Lesser", columnName]=descriptive.loc["Q1:25%", columnName]-descriptive.loc["1.5rule", columnName]
        descriptive.loc["Greater", columnName]=descriptive.loc["Q3:75%", columnName]+descriptive.loc["1.5rule", columnName]
        descriptive.loc["Min", columnName]=dataset[columnName].min()
        descriptive.loc["Max", columnName]=dataset[columnName].max()
    return descriptive

# %%
 Univariate(dataset,quan)
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4      91.15       88.5       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# Lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# Greater  322.0      98.35      91.15       88.5     118.75      78.72
# Min          1      40.89      42.75       50.0       50.0      51.21
# ...

# %%
# Initialize the lists to store columns with outliers
lesser = []
greater = []

# Function to find columns with outliers based on certain thresholds
def Outlier_Column(quan, dataset, descriptive):
    # Loop over each column in the 'quan' list
    for columnName in quan:
        # Check if the minimum value in the column is less than the 'Lesser' threshold
        if dataset[columnName].min() < descriptive[columnName]["Lesser"]:
            lesser.append(columnName)
        
        # Check if the maximum value in the column is greater than the 'Greater' threshold
        if dataset[columnName].max() > descriptive[columnName]["Greater"]:
            greater.append(columnName)
    
    # Return the lists of columns with outliers
    return lesser, greater

# %%
Outlier_Column(quan, dataset, descriptive)
# Out:
# ([], [])

# %%
def replace_outliers(dataset, lesser, greater, descriptive):
    for columnName in lesser:
        dataset.loc[dataset[columnName] < descriptive.loc["Lesser", columnName], columnName] = descriptive.loc["Lesser", columnName]
    
    for columnName in Greater:
        dataset.loc[dataset[columnName] > descriptive.loc["Greater", columnName], columnName] = descriptive.loc["Greater", columnName]
    
    return descriptive

# %%
replace_outliers(dataset, lesser, greater, descriptive)
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4      91.15       88.5       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# Lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# Greater  322.0      98.35      91.15       88.5     118.75      78.72
# Min          1      40.89      42.75       50.0       50.0      51.21
# ...
